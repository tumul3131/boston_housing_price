# %% [markdown]
# # BOSTON HOUSING PRICE PREDICTION

# %% [markdown]
# ## Step 1: Data Collection

# %% [markdown]
# The data was collected from https://www.kaggle.com/c/boston-housing/overview. The download file consists of train,test data and submission example for modelling. It is a boston housing price data with 14 columns.

# %% [markdown]
# ## Step 2: Data Preprocessing

# %%
#Import important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load and read the data
column_names = ['CRIM', 'ZN', 'INDUS','CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO','B', 'LSTAT', 'MEDV']
df=pd.read_csv('housing.csv',header=None,sep='\s+',names=column_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Let's learn about the features in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# The dataset consist of 14 columns and 505 records.

# %% [markdown]
# #### Handling Missing values

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# No missing values found in the data.

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# df['ZN'].value_counts()

# %% [markdown]
# ### Statistical Analysis:
# * count value of all the features are same, which signifies that their are no missing values in dataset.
# * 'CRIM' has mean of 3.61 while max value is 88.97, their is high chance of seeing outliers in this column.
# * 'ZN' also has most of its value in 75th quartile range and max value is 100, so it may have a possibility of outliers.
# * 'CHAS' has 25th, 50th, 75th Quartile as zero and min value of 0 and max value of 1, which means it is a categorical feature.
# * 'NOX' has balanced values, its mean and median have close values.
# * 'RM' shows that values arent much deviated form the mean, most of the values are closer to mean, less spread of data is seen.
# * 'AGE' has higher spread of values as its range is 97.1 (100-2.90) and standard deviation of 28.148.
# * 'DIS' has balanced values as mean and median have close values.
# * 'RAD' has its maximum value in 75th quartile which means it cannot have outliers, but the data is not skewed.
# * 'TAX' has a major spread of values and it has more distributed values.
# * 'PTRATIO' consists of evenly distributed data.
# * 'B' has chance of having outliers at the before the Q1 quartile.
# * 'LSTAT' might have outliers beacause of variation in mean and median values.
# * 'MEDV' may have outliers as the value in 75th Quartile id far away from the max value of MEDV.

# %% [markdown]
# #### Visualising outliers before scaling

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ##### Observations from Boxplot:
# * 'CRIM','ZN','B' seem to have many outliers. We need to handle these outliers. Let's see if scaling of data helps with handling outliers.

# %% [markdown]
# #### Let's detect outliers in 'CRIM','B' and 'ZN'

# %%
temp=df[['CRIM','ZN','B']]

# %%
# detect outliers using boxplot method
outliers = pd.DataFrame()
for column in  ['CRIM','ZN','B']:
    
    Q1 = temp[column].quantile(0.25)
    Q3 = temp[column].quantile(0.75)
    
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    column_outliers = temp[(temp[column] < lower_bound) | (temp[column] > upper_bound)]
    outliers = pd.concat([outliers, column_outliers]) #concate the detected outlier in outlier

# %%
print(len(outliers))
# Out:
# 211

# %%
print(round((len(outliers)/len(df))*100),'% of data as outliers.')
# Out:
# 42 % of data as outliers.

# %% [markdown]
# Now, we can't remove all these data points because it will lead to loss of data and might affect the prediction. They may contain a valuable information, so we may not remove them.

# %% [markdown]
# #### Data Distribution

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
for column in df:
    plt.figure(figsize=(10, 6))
    
    # Plot the KDE (Kernel Density Estimate)
    sns.kdeplot(df[column], color="green", fill=True, alpha=0.3)
    
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.title(f'Density Plot of {column}')
    
    # Show the plot
    plt.show()

# %% [markdown]
# ### Performing feature scaling
# * 'CHAS' is categrorical so we will avoid their scaling.
# * Also scaling of 'MEDV' is not done as it is a target variable.
# * 'MEDV' is highly correlated with 'RM'

# %%
df_scaled=df.copy()
df_scaled.head()
numeric_col =['CRIM','ZN','INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO','B', 'LSTAT']
for i in numeric_col :
        df_scaled[i]=(df_scaled[i]-df_scaled[i].mean())/(df_scaled[i].std())
        
df_scaled.head()
# Out:
#        CRIM        ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0 -0.419367  0.284548 -1.286636     0 -0.144075  0.413263 -0.119895  0.140075
# 1 -0.416927 -0.487240 -0.592794     0 -0.739530  0.194082  0.366803  0.556609
# 2 -0.416929 -0.487240 -0.592794     0 -0.739530  1.281446 -0.265549  0.556609
# 3 -0.416338 -0.487240 -1.305586     0 -0.834458  1.015298 -0.809088  1.076671
# 4 -0.412074 -0.487240 -1.305586     0 -0.834458  1.227362 -0.510674  1.076671
#
#         RAD       TAX   PTRATIO         B     LSTAT  MEDV
# 0 -0.981871 -0.665949 -1.457558  0.440616 -1.074499  24.0
# 1 -0.867024 -0.986353 -0.302794  0.440616 -0.491953  21.6
# 2 -0.867024 -0.986353 -0.302794  0.396035 -1.207532  34.7
# 3 -0.752178 -1.105022  0.112920  0.415751 -1.360171  33.4
# 4 -0.752178 -1.105022  0.112920  0.440616 -1.025487  36.2

# %% [markdown]
# ## SPLITTING THE DATA

# %%
print(type(df_scaled.drop('MEDV',axis=1)))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.model_selection import train_test_split

X = df_scaled.drop('MEDV',axis=1)
Y = df_scaled['MEDV']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 477  1.326491 -0.487240  1.014995     0  0.511789 -1.395688  1.020471
# 15  -0.347162 -0.487240 -0.436826     0 -0.144075 -0.641365 -0.428966
# 332 -0.416072  1.013460 -0.740017     0 -1.007917 -0.360985 -1.608410
# 423  0.399567 -0.487240  1.014995     0  0.511789 -0.258511  0.587061
# 19  -0.335721 -0.487240 -0.436826     0 -0.144075 -0.793653  0.032865
# ..        ...       ...       ...   ...       ...       ...       ...
# 106 -0.400198 -0.487240 -0.375604     0 -0.299411 -0.638519  0.828634
# 270 -0.385322  0.370303 -0.608829     0 -0.782679 -0.610054 -0.940532
# 348 -0.418357  2.942931 -1.330366     0 -1.032943  0.498658 -1.381047
# 435  0.877386 -0.487240  1.014995     0  1.599143  0.490118  0.924552
# 102 -0.393506 -0.487240 -0.375604     0 -0.299411  0.171310  0.597719
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# 477 -0.804642  1.659603  1.529413  0.805778 -0.078800  1.716403
# 15   0.334119 -0.637331 -0.600682  1.175303  0.426595 -0.585776
# 332  1.351400 -0.981871 -0.618482 -0.718509  0.061076 -0.675399
# 423 -0.842111  1.659603  1.529413  0.805778 -3.879233  1.489546
# 19   0.000692 -0.637331 -0.600682  1.175303  0.375442 -0.192277
# ..        ...       ...       ...       ...       ...       ...
# 106 -0.752261 -0.522484 -0.143809  1.129112  0.427143  0.841183
# 270  0.301066 -0.752178 -1.099088  0.066730  0.350249  0.048583
# 348  2.160296 -0.637331 -0.760884 -0.672319  0.375333 -0.933063
# 435 -0.793244  1.659603  1.529413  0.805778 -2.703592  1.486745
# 102 -0.513054 -0.522484 -0.143809  1.129112 -3.131327 -0.283300
#
# [404 rows x 13 columns]

# %%
X_train.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %% [markdown]
# # MODEL DEVELOPMENT

# %% [markdown]
# ### LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression() 
lr = lr.fit(X_train,Y_train)
Y_pred = lr.predict(X_test)

# %%
print(Y_pred)
# Out:
# [28.99672362 36.02556534 14.81694405 25.03197915 18.76987992 23.25442929
#  17.66253818 14.34119    23.01320703 20.63245597 24.90850512 18.63883645
#  -6.08842184 21.75834668 19.23922576 26.19319733 20.64773313  5.79472718
#  40.50033966 17.61289074 27.24909479 30.06625441 11.34179277 24.16077616
#  17.86058499 15.83609765 22.78148106 14.57704449 22.43626052 19.19631835
#  22.43383455 25.21979081 25.93909562 17.70162434 16.76911711 16.95125411
#  31.23340153 20.13246729 23.76579011 24.6322925  13.94204955 32.25576301
#  42.67251161 17.32745046 27.27618614 16.99310991 14.07009109 25.90341861
#  20.29485982 29.95339638 21.28860173 34.34451856 16.04739105 26.22562412
#  39.53939798 22.57950697 18.84531367 32.72531661 25.0673037  12.88628956
#  22.68221908 30.48287757 31.52626806 15.90148607 20.22094826 16.71089812
#  20.52384893 25.96356264 30.61607978 11.59783023 20.51232627 27.48111878
#  11.01962332 15.68096344 23.79316251  6.19929359 21.6039073  41.41377225
#  18.76548695  8.87931901 20.83076916 13.25620627 20.73963699  9.36482222
#  23.22444271 31.9155003  19.10228271 25.51579303 29.04256769 20.14358566
#  25.5859787   5.70159447 20.09474756 14.95069156 12.50395648 20.72635294
#  24.73957161 -0.164237   13.68486682 16.18359697 22.27621999 24.47902364]

# %%
print(Y_pred.shape)
print(X_test.shape)
# Out:
# (102,)
# (102, 13)

# %%
#Scale and Intercept:
display(lr.coef_) 
display(lr.intercept_)
# Out:
# array([-0.97245563,  0.70224988,  0.27702599,  2.7844382 , -1.99340117,
#         3.11880171, -0.17723543, -3.04878477,  2.28504378, -1.79437865,
#        -1.98191289,  1.12761343, -3.63173982])
# 22.292668758837102

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error

display(r2_score(Y_test, Y_pred))
display(mean_absolute_error(Y_test, Y_pred))
display(mean_squared_error(Y_test, Y_pred))
# Out:
# 0.6687594935356325
# 3.189091965887846
# 24.291119474973485

# %%
plt.scatter(Y_test,Y_pred, color='green')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Predicted Price")
plt.show()

# %% [markdown]
# #### MODEL EVALUATION

# %% [markdown]
# ## DECESION TREE REGRESSOR

# %%
# from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(random_state=42)
dtr=dtr.fit(X_train,Y_train)
Y_pred=dtr.predict(X_test)

# %%
Y_pred
# Out:
# array([28.1, 33.1, 17.3, 22. , 23.2, 18.5, 16.6, 16.6, 22.7, 22. , 20.5,
#        27.1,  8.4, 21.4, 18.5, 23.9, 18.8, 10.5, 46. , 13. , 23.1, 24.4,
#        13.6, 22. , 14.5, 11.7, 21. , 13.5, 19.4, 20.7, 18.8, 23.1, 10.4,
#        16.2, 13.3, 13.1, 33.4, 18.5, 20.4, 24.8, 19.8, 28.4, 46. , 19.3,
#        22. , 13. , 14.9, 24.1, 17.7, 32. , 21.7, 36.1, 16.7, 28.4, 43.1,
#        18.5, 15.2, 22.8, 22. , 22.5, 24.5, 33. , 29.4, 19.3, 26.6, 14.4,
#        13. , 22.9, 22.8, 14.1, 21.8, 28.7,  8.3, 18.6, 21.5, 10.5, 19.8,
#        50. , 13.3,  8.1, 21.2, 16.3, 19.4, 10.5, 14.5, 29.9, 14.8, 23.1,
#        22.9, 18. , 23.3,  8.8, 19.2, 17.6, 16.2, 19.3, 50. , 16.3, 11.7,
#        16.3, 19. , 26.4])

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error

display(r2_score(Y_test, Y_pred))
display(mean_absolute_error(Y_test, Y_pred))
display(mean_squared_error(Y_test, Y_pred))
# Out:
# 0.8579634380978161
# 2.394117647058824
# 10.416078431372549

# %%
plt.scatter(Y_test,Y_pred, color='green')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Predicted Price")
plt.show()

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=3)
rfr=rfr.fit(X_train,Y_train)
Y_pred=rfr.predict(X_test)

# %%
Y_pred
# Out:
# array([22.50067691, 27.17960094, 16.61364729, 24.00589022, 15.6300998 ,
#        21.92353185, 17.66530717, 15.76590718, 21.92353185, 21.76967018,
#        17.66530717, 17.66530717, 11.8781246 , 21.92353185, 21.85952329,
#        28.3344199 , 17.27244981, 11.98936369, 44.48257496, 13.59736941,
#        23.70730734, 23.46319231, 16.05133337, 23.58630496, 14.54212499,
#        14.90187357, 22.39315501, 13.82912435, 17.66530717, 21.85952329,
#        18.65932788, 23.46319231, 31.05446047, 21.85952329, 15.72373599,
#        16.00518403, 33.50102409, 22.01176616, 18.61581455, 23.26413107,
#        16.69863882, 27.29652163, 44.6945358 , 21.85952329, 22.57351886,
#        13.66363157, 17.00970265, 23.54472041, 16.83714316, 25.75140864,
#        21.90303662, 30.49495761, 17.00970265, 25.02585991, 45.80311338,
#        21.92353185, 14.74243854, 29.65927779, 22.29426795, 17.66530717,
#        24.38979652, 32.78007328, 26.6210157 , 21.85952329, 25.43899199,
#        16.70693789, 13.36624242, 23.54472041, 26.03108285, 15.57002428,
#        21.85952329, 25.53290803, 11.98936369, 24.00589022, 21.92353185,
#        11.8781246 , 21.92353185, 44.7554744 , 11.98809936, 15.50853918,
#        22.46599697, 13.34495521, 22.43666834, 11.98936369, 21.85952329,
#        24.80166792, 15.8071404 , 23.70730734, 23.70730734, 17.81701673,
#        21.90303662, 11.8781246 , 21.92353185, 21.85952329, 24.17131725,
#        21.92353185, 33.06158404, 12.96689413, 13.15117276, 13.18810799,
#        21.85952329, 22.53000553])

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error

display(r2_score(Y_test, Y_pred))
display(mean_absolute_error(Y_test, Y_pred))
display(mean_squared_error(Y_test, Y_pred))
# Out:
# 0.8104104600838794
# 2.6989591657431813
# 13.903318209674184

# %%
plt.scatter(Y_test,Y_pred, color='green')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Predicted Price")
plt.show()

# %% [markdown]
# ## XGBOOST REGRESSION

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb=xgb.fit(X_train, Y_train)
Y_pred=xgb.predict(X_test)

# %%
Y_pred
# Out:
# array([24.276764 , 30.46075  , 17.959005 , 22.965069 , 17.133715 ,
#        22.163433 , 18.669397 , 15.236069 , 21.046127 , 20.459925 ,
#        22.439089 , 18.89959  , 11.203732 , 21.811333 , 18.655327 ,
#        26.25912  , 21.139784 ,  9.210471 , 47.378334 , 15.913627 ,
#        25.087412 , 26.079153 , 13.452615 , 21.082066 , 15.193554 ,
#        15.992098 , 20.690847 , 13.094459 , 21.131876 , 21.168287 ,
#        18.848736 , 23.033901 , 14.877705 , 21.35931  , 15.263533 ,
#        14.96528  , 33.754707 , 19.01804  , 22.69863  , 24.285683 ,
#        19.455326 , 27.735622 , 47.043087 , 19.217285 , 21.663893 ,
#        14.770664 , 13.908811 , 23.762539 , 17.538256 , 25.872328 ,
#        22.392021 , 35.081337 , 17.318087 , 27.144457 , 45.176407 ,
#        21.917618 , 16.05219  , 30.757784 , 22.377308 , 19.42954  ,
#        25.34448  , 34.943123 , 30.451046 , 17.93282  , 25.573687 ,
#        17.035986 , 14.910609 , 22.595358 , 27.416218 , 14.8786125,
#        20.446955 , 30.664629 ,  9.616146 , 21.455444 , 22.940966 ,
#         6.722242 , 19.879969 , 46.798008 ,  9.669527 , 13.117878 ,
#        21.28643  , 11.787285 , 21.489807 ,  8.746218 , 19.149298 ,
#        27.94858  , 15.95009  , 23.537941 , 23.592808 , 18.32834  ,
#        22.520878 ,  8.653    , 19.500591 , 18.919949 , 21.414    ,
#        19.623476 , 37.574116 , 11.571929 , 13.430772 , 13.622202 ,
#        20.457579 , 23.422758 ], dtype=float32)

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error

display(r2_score(Y_test, Y_pred))
display(mean_absolute_error(Y_test, Y_pred))
display(mean_squared_error(Y_test, Y_pred))
# Out:
# 0.9057837838492537
# 1.8908873698290656
# 6.909231565384943

# %%
plt.scatter(Y_test,Y_pred, color='green')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Predicted Price")
plt.show()
